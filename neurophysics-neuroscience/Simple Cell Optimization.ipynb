# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload

# %%
# Lets get the bluepyopt first
# !pip install bluepyopt
# Out:
# ...
#     100% |████████████████████████████████| 61kB 1.9MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 942kB 788kB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 81kB 5.3MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 604kB 1.2MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 194kB 3.3MB/s eta 0:00:01
# ...
#   Running setup.py bdist_wheel for bluepyopt ... done
#   Stored in directory: /Users/tarrysingh/Library/Caches/pip/wheels/14/13/0b/e52dff870932467bdb4685fa27d5a3c00b6045a0a02b6336d8
#   Running setup.py bdist_wheel for deap ... done
#   Stored in directory: /Users/tarrysingh/Library/Caches/pip/wheels/82/aa/67/2c93e17c84646c86099fda53ee0b3329372dcf94dd8789fd13
#   Running setup.py bdist_wheel for efel ... error
# ...
