# %% [markdown]
# ## More of Shor Algorithm

# %% [markdown]
# ### Code usage
#
# Usage:
#
# `python shors.py [-p|--periods PERIODS] [-a|--attempts ATTEMPTS] [-n|--neighborhood NEIGHBORHOOD] [-v|--verbose] N`
#
# **Credit** : Todd Wilde, link to [original code](https://github.com/toddwildey/shors-python)

# %%
# !python shor2.py 15
# Out:
# N = 15
# Neighborhood = 1
# Number of periods = 2
#
# Attempt #0
# Finding the period...
# Q = 256	a = 2
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 2
# Performing a measurement on the periodicity register
# QFT register measured	x = 64
# Finding the period via continued fractions
# Candidate period	r = 4
# Checking candidate period, nearby values, and multiples
# Period found	r = 4
#
# Attempt #1
# Finding the period...
# Q = 256	a = 7
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 4
# Performing a measurement on the periodicity register
# QFT register measured	x = 192
# Finding the period via continued fractions
# Candidate period	r = 4
# Checking candidate period, nearby values, and multiples
# Period found	r = 4
#
# Finding least common multiple of all periods
# Factors:	5, 3

# %%
! python shor2.py 25
# Out:
# N = 25
# Neighborhood = 1
# Number of periods = 2
#
# Attempt #0
# Finding the period...
# Q = 1024	a = 12
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 19
# Performing a measurement on the periodicity register
# QFT register measured	x = 870
# Finding the period via continued fractions
# Candidate period	r = 20
# Checking candidate period, nearby values, and multiples
# Period was trivial, re-attempt
#
# Attempt #1
# Found factors classically, re-attempt
#
# Attempt #2
# Finding the period...
# Q = 1024	a = 2
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 24
# Performing a measurement on the periodicity register
# QFT register measured	x = 461
# Finding the period via continued fractions
# Candidate period	r = 20
# Checking candidate period, nearby values, and multiples
# Period was trivial, re-attempt
#
# Attempt #3
# Finding the period...
# Q = 1024	a = 22
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 19
# Performing a measurement on the periodicity register
# QFT register measured	x = 614
# Finding the period via continued fractions
# Candidate period	r = 5
# Checking candidate period, nearby values, and multiples
# Period was not found, re-attempt
#
# Attempt #4
# Finding the period...
# Q = 1024	a = 22
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 4
# Performing a measurement on the periodicity register
# QFT register measured	x = 973
# Finding the period via continued fractions
# Candidate period	r = 20
# Checking candidate period, nearby values, and multiples
# Period was trivial, re-attempt
#
# Attempt #5
# Found factors classically, re-attempt
#
# Attempt #6
# Found factors classically, re-attempt
#
# Attempt #7
# Finding the period...
# Q = 1024	a = 24
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 1
# Performing a measurement on the periodicity register
# QFT register measured	x = 512
# Finding the period via continued fractions
# Candidate period	r = 2
# Checking candidate period, nearby values, and multiples
# Period was trivial, re-attempt
#
# Attempt #8
# Finding the period...
# Q = 1024	a = 4
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 24
# Performing a measurement on the periodicity register
# QFT register measured	x = 412
# Finding the period via continued fractions
# Candidate period	r = 5
# Checking candidate period, nearby values, and multiples
# Period was trivial, re-attempt
#
# Attempt #9
# Finding the period...
# Q = 1024	a = 13
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 21
# Performing a measurement on the periodicity register
# QFT register measured	x = 51
# Finding the period via continued fractions
# Candidate period	r = 20
# Checking candidate period, nearby values, and multiples
# Period was trivial, re-attempt
#
# Attempt #10
# Finding the period...
# Q = 1024	a = 4
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 24
# Performing a measurement on the periodicity register
# QFT register measured	x = 104
# Finding the period via continued fractions
# Candidate period	r = 10
# Checking candidate period, nearby values, and multiples
# Period was trivial, re-attempt
#
# Attempt #11
# Finding the period...
# Q = 1024	a = 14
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 16
# Performing a measurement on the periodicity register
# QFT register measured	x = 410
# Finding the period via continued fractions
# Candidate period	r = 5
# Checking candidate period, nearby values, and multiples
# Period was trivial, re-attempt
#
# Attempt #12
# Finding the period...
# Q = 1024	a = 14
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 16
# Performing a measurement on the periodicity register
# QFT register measured	x = 819
# Finding the period via continued fractions
# Candidate period	r = 5
# Checking candidate period, nearby values, and multiples
# Period was trivial, re-attempt
#
# Attempt #13
# Found factors classically, re-attempt
#
# Attempt #14
# Finding the period...
# Q = 1024	a = 11
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 16
# Performing a measurement on the periodicity register
# QFT register measured	x = 409
# Finding the period via continued fractions
# Candidate period	r = 5
# Checking candidate period, nearby values, and multiples
# Period was odd, re-attempt
#
# Attempt #15
# Finding the period...
# Q = 1024	a = 7
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 7
# Performing a measurement on the periodicity register
# QFT register measured	x = 0
# Finding the period via continued fractions
# Candidate period	r = 0
# Checking candidate period, nearby values, and multiples
# Period was trivial, re-attempt
#
# Attempt #16
# Finding the period...
# Q = 1024	a = 3
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 6
# Performing a measurement on the periodicity register
# QFT register measured	x = 0
# Finding the period via continued fractions
# Candidate period	r = 0
# Checking candidate period, nearby values, and multiples
# Period was trivial, re-attempt
#
# Attempt #17
# Finding the period...
# Q = 1024	a = 2
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 24
# Performing a measurement on the periodicity register
# QFT register measured	x = 870
# Finding the period via continued fractions
# Candidate period	r = 20
# Checking candidate period, nearby values, and multiples
# Period was trivial, re-attempt
#
# Attempt #18
# Finding the period...
# Q = 1024	a = 14
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 6
# Performing a measurement on the periodicity register
# QFT register measured	x = 512
# Finding the period via continued fractions
# Candidate period	r = 2
# Checking candidate period, nearby values, and multiples
# Period was not found, re-attempt
#
# Attempt #19
# Finding the period...
# Q = 1024	a = 22
# Registers generated
# Performing Hadamard on input register
# Hadamard complete
# Mapping input register to output register, where f(x) is a^x mod N
# Modular exponentiation complete
# Performing quantum Fourier transform on output register
# Quantum Fourier transform complete
# Performing a measurement on the output register
# Output register measured	y = 13
# Performing a measurement on the periodicity register
# QFT register measured	x = 973
# Finding the period via continued fractions
# Candidate period	r = 20
# Checking candidate period, nearby values, and multiples
# Period was trivial, re-attempt
